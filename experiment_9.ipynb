# %% [markdown]
# <a href="https://colab.research.google.com/github/arddrasoni-commits/9_pandas/blob/main/experiment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 9
# ## Name: Arddra Soni
# ## PRN: 25070123022
# ## Branch: ENTC
# ## Div. : A1
# ### Study of Pandas

# %%
# Pandas = "Panel Data"

# %%
import pandas as pd

s = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Create dataframe
data = {
    "Name":["P","Q","R"],
    "Marks":[90,85,78]
    }
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    P     90
# 1    Q     85
# 2    R     78

# %%
df.head()
df.tail()
# Out:
#   Name  Marks
# 0    P     90
# 1    Q     85
# 2    R     78

# %%
df.shape #Find the structure of the dataframe
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
# samples = rows, features = columns, rows x columns = total no.of elements

# %%
 # display column names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
# check datatypes of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
# access individual column
df["Name"]
# Out:
# 0    P
# 1    Q
# 2    R
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    90
# 1    85
# 2    78
# Name: Marks, dtype: int64

# %%
# Access specific row
df.loc[1]
# Out:
# Name      Q
# Marks    85
# Name: 1, dtype: object

# %%
df.iloc[1] #used with dataset
# Out:
# Name      Q
# Marks    85
# Name: 1, dtype: object

# %%
# Update data in dataframe

# Change marks of student A to 88

df.loc[0,"Marks"] = 88
df
# Out:
#   Name  Marks
# 0    P     88
# 1    Q     85
# 2    R     78

# %%
#add a new column

df["Grade"] = ["First Class","Distinction","Second Class"]
df
# Out:
#   Name  Marks         Grade
# 0    P     88   First Class
# 1    Q     85   Distinction
# 2    R     78  Second Class

# %%
# Delete a column
df.drop("Grade", axis=1, inplace=True)
df
# Out:
#   Name  Marks
# 0    P     88
# 1    Q     85
# 2    R     78

# %%
# Perform Basic Statistical analysis
df["Marks"].mean()
# Out:
# np.float64(83.66666666666667)

# %%
df["Marks"].max()
# Out:
# 88

# %%
df["Marks"].min()
# Out:
# 78

# %%
# Apply Condition (Filtering)

# Display students scoring more than 80
df[df["Marks"] > 80]
# Out:
#   Name  Marks
# 0    P     88
# 1    Q     85
